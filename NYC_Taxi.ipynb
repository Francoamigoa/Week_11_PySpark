# %%
import pandas as pd
import time
from pyspark.sql.functions import col, count, avg, sum as spark_sum, desc, when

# Verify Spark is ready (spark is pre-created in Databricks)
print(f"✅ Spark version: {spark.version}")
print(f"✅ Ready to go!")
# Out:
# ✅ Spark version: 4.0.0
# ✅ Ready to go!

# %% [markdown]
# ### Operation 1: Load the Data

# %%
df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv("dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_200[6-9]-*.csv.gz,"
         "dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-*.csv.gz")
)

# %% [markdown]
# ### Operation 2: Apply transformations

# %%
from pyspark.sql import functions as F

df_clean = (
    df
    .withColumn("pickup_ts", F.to_timestamp("pickup_datetime", "yyyy-MM-dd HH:mm:ss"))
    .withColumn("dropoff_ts", F.to_timestamp("dropoff_datetime", "yyyy-MM-dd HH:mm:ss"))
)

# %% [markdown]
# ## Transformation

# %%
df_feat = (
    df_clean
    .withColumn("trip_minutes", (F.col("dropoff_ts").cast("long") - F.col("pickup_ts").cast("long")) / 60.0)
    .withColumn("year", F.year("pickup_ts"))
    .withColumn("month", F.month("pickup_ts"))
    .withColumn("hour", F.hour("pickup_ts"))
)

# %% [markdown]
# ##Filter

# %%
df_f = (
    df_feat
    .filter(F.col("pickup_datetime").startswith("2010-"))
    .filter(F.col("trip_distance") > 0)
    .filter(F.col("fare_amount") >= 0)
    .filter(F.col("pickup_ts").isNotNull() & F.col("dropoff_ts").isNotNull())
)

# %%
agg_pay_month = (
    df_f.groupBy("month", "payment_type")
        .agg(
            F.count("*").alias("n_trips"),
            F.avg("fare_amount").alias("avg_fare"),
            F.avg("tip_amount").alias("avg_tip"),
            F.avg("trip_distance").alias("avg_distance"),
            F.avg("trip_minutes").alias("avg_duration")
        )
        .orderBy( "month")
)

# %% [markdown]
# ## SQL Queries

# %%
df_f.createOrReplaceTempView("df_f")
# 99 percentile tip by month
sql_99_percentile_tip_by_month = spark.sql("""
SELECT  month,
       percentile_approx(tip_amount, 0.99) AS 99_tip_amount
FROM df_f
GROUP BY month
ORDER BY month
""")

# Average trips per day by day of week
sql_avg_trips_by_dow = spark.sql("""
SELECT
  date_format(pickup_ts, 'E') AS dow,
  COUNT(*) / COUNT(DISTINCT date(pickup_ts)) AS avg_trips_per_day
FROM df_f
WHERE pickup_ts IS NOT NULL
GROUP BY date_format(pickup_ts, 'E')
ORDER BY avg_trips_per_day DESC
""")

# %%
#show results
agg_pay_month.show()
sql_99_percentile_tip_by_month.show()
sql_avg_trips_by_dow.show()
# Out:
# +-----+------------+-------+------------------+--------------------+------------------+------------------+
# |month|payment_type|n_trips|          avg_fare|             avg_tip|      avg_distance|      avg_duration|
# +-----+------------+-------+------------------+--------------------+------------------+------------------+
# |    1|         Dis|   5931|12.137599055808462|0.026538526386781326|3.6906086663294517|12.408028438149804|
# |    1|         No |  27588|10.375210236334613| 0.01422502537335073|2.9222560533565365| 11.28149799429708|
# |    1|         CRE| 241539|11.338242561242701|  2.1906308712049785| 3.398023921602689|14.455690799415436|
# |    1|         CAS|5600983| 8.890324505547309|1.493487839545308...| 2.460610835633479|10.428857163704018|
# |    1|         Cas|4403194| 8.640615823428492|0.002560668460213...| 2.345022317889869| 9.884501886584824|
# |    1|         Cre|4500656| 10.54006692580258|   2.049957021820885| 3.118497241290966|12.144309488808913|
# |    2|         CRE|2074020| 10.37784511721158|  1.9417515260227285| 34.74181063827657|12.159036838281374|
# |    2|         NA |  31640|10.915255056890024|0.017767383059418457| 22.28940581542298|11.806957437842474|
# |    2|         CRD|1780516|10.689270571001881|  1.2064465862704994| 3.304646512583884|12.880389168083859|
# |    2|         CSH|3288698| 8.987244325870902|1.508195644598561...|2.4422918826840005|10.777976775814217|
# |    2|         CAS|3896515| 8.717203064792876|0.003022608664409089|33.196250315987584|10.236545665378605|
# |    3|         CSH|3830511| 9.182914517151467|7.113933362937739...|3.2414785233610908|11.034245039369424|
# |    3|         CRD|2103327|11.077141438302332|   1.486192099469507|10.049000512045328| 13.30148046404577|
# |    3|         Dis|   6535|12.149430757459816|0.022947207345065036|2066.4226778882808|13.230400408059111|
# |    3|         Cas|4460097| 9.015485483842587|0.002864527385839...|42.382676430575025|10.917406123678786|
# |    3|         Cre|2365639|10.767932554376081|  2.0019835697674773| 66.97713869275196|12.709052613972895|
# |    3|         No |  26854|11.157010501228719|0.017420496015491175|107.60834140165782|11.877009011692857|
# |    4|         No |  25452|10.577705484834008| 0.01488684582743989| 2.934574886060017| 11.38047763109656|
# |    4|         CAS|5428351| 9.330256081458826|8.516398442178849E-6|2.5686902726070153| 11.36141983388076|
# |    4|         Cre|4999989|10.921275058808146|  2.0922272229000405|3.1976708308755035|13.013161898955612|
# +-----+------------+-------+------------------+--------------------+------------------+------------------+
# only showing top 20 rows
# +-----+-------------+
# |month|99_tip_amount|
# +-----+-------------+
# |    1|         6.07|
# |    2|         6.21|
# |    3|         6.72|
# |    4|          6.6|
# |    5|         6.87|
# |    6|          7.0|
# |    7|         6.79|
# |    8|         6.83|
# |    9|          7.0|
# |   10|          7.0|
# |   11|         7.02|
# |   12|          7.0|
# +-----+-------------+
#
# +---+------------------+
# |dow| avg_trips_per_day|
# +---+------------------+
# |Fri|493155.71698113205|
# |Sat| 481120.0961538461|
# |Thu| 478421.4905660377|
# |Wed|470392.32692307694|
# |Tue| 445185.5094339623|
# |Sun|425900.92307692306|
# |Mon| 411106.0961538461|
# +---+------------------+

# %% [markdown]
# ### Write to Parquet (the code is in "coment" format because Databricks permission)

# %%
#agg_pay_month.write.parquet("output.parquet")
#sql_99_percentile_tip_by_month.write.parquet("output.parquet")
#sql_avg_trips_by_dow.write.parquet("output.parquet")

# %% [markdown]
# ## Execution Plans

# %%
agg_pay_month.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (17)
# +- == Initial Plan ==
#    ColumnarToRow (16)
#    +- PhotonResultStage (15)
#       +- PhotonSort (14)
#          +- PhotonShuffleExchangeSource (13)
#             +- PhotonShuffleMapStage (12)
#                +- PhotonShuffleExchangeSink (11)
#                   +- PhotonGroupingAgg (10)
#                      +- PhotonShuffleExchangeSource (9)
#                         +- PhotonShuffleMapStage (8)
#                            +- PhotonShuffleExchangeSink (7)
#                               +- PhotonGroupingAgg (6)
#                                  +- PhotonProject (5)
#                                     +- PhotonProject (4)
#                                        +- PhotonFilter (3)
#                                           +- PhotonRowToColumnar (2)
#                                              +- Scan csv  (1)
#
#
# (1) Scan csv
# Output [6]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-01.csv.gz, ... 11 entries]
# PushedFilters: [IsNotNull(trip_distance), IsNotNull(fare_amount), GreaterThan(trip_distance,0.0)]
# ReadSchema: struct<pickup_datetime:timestamp,dropoff_datetime:timestamp,trip_distance:double,payment_type:string,fare_amount:string,tip_amount:double>
#
# (2) PhotonRowToColumnar
# Input [6]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526]
#
# (3) PhotonFilter
# Input [6]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526]
# Arguments: (((((isnotnull(trip_distance#12515) AND isnotnull(fare_amount#12523)) AND (trip_distance#12515 > 0.0)) AND (cast(fare_amount#12523 as int) >= 0)) AND isnotnull(gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false))) AND isnotnull(gettimestamp(dropoff_datetime#12513, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)))
#
# (4) PhotonProject
# Input [6]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526]
# Arguments: [trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526, gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false) AS pickup_ts#14755, gettimestamp(dropoff_datetime#12513, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false) AS dropoff_ts#14757]
#
# (5) PhotonProject
# Input [6]: [trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526, pickup_ts#14755, dropoff_ts#14757]
# Arguments: [trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526, (cast((cast(dropoff_ts#14757 as bigint) - cast(pickup_ts#14755 as bigint)) as double) / 60.0) AS trip_minutes#14760, month(cast(pickup_ts#14755 as date)) AS month#14764]
#
# (6) PhotonGroupingAgg
# Input [6]: [trip_distance#12515, payment_type#12522, fare_amount#12523, tip_amount#12526, trip_minutes#14760, month#14764]
# Arguments: [month#14764, payment_type#12522], [partial_count(1) AS count#16702L, partial_avg(cast(fare_amount#12523 as double)) AS (sum#16705, count#16706L), partial_avg(tip_amount#12526) AS (sum#16709, count#16710L), partial_avg(trip_distance#12515) AS (sum#16713, count#16714L), partial_avg(trip_minutes#14760) AS (sum#16717, count#16718L)], [count#16701L, sum#16703, count#16704L, sum#16707, count#16708L, sum#16711, count#16712L, sum#16715, count#16716L], [month#14764, payment_type#12522, count#16702L, sum#16705, count#16706L, sum#16709, count#16710L, sum#16713, count#16714L, sum#16717, count#16718L], false
#
# (7) PhotonShuffleExchangeSink
# Input [11]: [month#14764, payment_type#12522, count#16702L, sum#16705, count#16706L, sum#16709, count#16710L, sum#16713, count#16714L, sum#16717, count#16718L]
# Arguments: hashpartitioning(month#14764, payment_type#12522, 1024)
#
# (8) PhotonShuffleMapStage
# Input [11]: [month#14764, payment_type#12522, count#16702L, sum#16705, count#16706L, sum#16709, count#16710L, sum#16713, count#16714L, sum#16717, count#16718L]
# Arguments: ENSURE_REQUIREMENTS, [id=#17696]
#
# (9) PhotonShuffleExchangeSource
# Input [11]: [month#14764, payment_type#12522, count#16702L, sum#16705, count#16706L, sum#16709, count#16710L, sum#16713, count#16714L, sum#16717, count#16718L]
#
# (10) PhotonGroupingAgg
# Input [11]: [month#14764, payment_type#12522, count#16702L, sum#16705, count#16706L, sum#16709, count#16710L, sum#16713, count#16714L, sum#16717, count#16718L]
# Arguments: [month#14764, payment_type#12522], [finalmerge_count(merge count#16702L) AS count(1)#16696L, finalmerge_avg(merge sum#16705, count#16706L) AS avg(fare_amount)#16697, finalmerge_avg(merge sum#16709, count#16710L) AS avg(tip_amount)#16698, finalmerge_avg(merge sum#16713, count#16714L) AS avg(trip_distance)#16699, finalmerge_avg(merge sum#16717, count#16718L) AS avg(trip_minutes)#16700], [count(1)#16696L, avg(fare_amount)#16697, avg(tip_amount)#16698, avg(trip_distance)#16699, avg(trip_minutes)#16700], [month#14764, payment_type#12522, count(1)#16696L AS n_trips#16110L, avg(fare_amount)#16697 AS avg_fare#16111, avg(tip_amount)#16698 AS avg_tip#16112, avg(trip_distance)#16699 AS avg_distance#16113, avg(trip_minutes)#16700 AS avg_duration#16114], true
#
# (11) PhotonShuffleExchangeSink
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
# Arguments: rangepartitioning(month#14764 ASC NULLS FIRST, 1024)
#
# (12) PhotonShuffleMapStage
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
# Arguments: ENSURE_REQUIREMENTS, [id=#17702]
#
# (13) PhotonShuffleExchangeSource
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
#
# (14) PhotonSort
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
# Arguments: [month#14764 ASC NULLS FIRST]
#
# (15) PhotonResultStage
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
#
# (16) ColumnarToRow
# Input [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
#
# (17) AdaptiveSparkPlan
# Output [7]: [month#14764, payment_type#12522, n_trips#16110L, avg_fare#16111, avg_tip#16112, avg_distance#16113, avg_duration#16114]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
sql_99_percentile_tip_by_month.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (16)
# +- == Initial Plan ==
#    ColumnarToRow (15)
#    +- PhotonResultStage (14)
#       +- PhotonSort (13)
#          +- PhotonShuffleExchangeSource (12)
#             +- PhotonShuffleMapStage (11)
#                +- PhotonShuffleExchangeSink (10)
#                   +- PhotonGroupingAgg (9)
#                      +- PhotonShuffleExchangeSource (8)
#                         +- PhotonShuffleMapStage (7)
#                            +- PhotonShuffleExchangeSink (6)
#                               +- PhotonGroupingAgg (5)
#                                  +- PhotonProject (4)
#                                     +- PhotonFilter (3)
#                                        +- PhotonRowToColumnar (2)
#                                           +- Scan csv  (1)
#
#
# (1) Scan csv
# Output [5]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523, tip_amount#12526]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-01.csv.gz, ... 11 entries]
# PushedFilters: [IsNotNull(trip_distance), IsNotNull(fare_amount), GreaterThan(trip_distance,0.0)]
# ReadSchema: struct<pickup_datetime:timestamp,dropoff_datetime:timestamp,trip_distance:double,fare_amount:string,tip_amount:double>
#
# (2) PhotonRowToColumnar
# Input [5]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523, tip_amount#12526]
#
# (3) PhotonFilter
# Input [5]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523, tip_amount#12526]
# Arguments: (((((isnotnull(trip_distance#12515) AND isnotnull(fare_amount#12523)) AND (trip_distance#12515 > 0.0)) AND (cast(fare_amount#12523 as int) >= 0)) AND isnotnull(gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false))) AND isnotnull(gettimestamp(dropoff_datetime#12513, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)))
#
# (4) PhotonProject
# Input [5]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523, tip_amount#12526]
# Arguments: [tip_amount#12526, month(cast(gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false) as date)) AS month#14764]
#
# (5) PhotonGroupingAgg
# Input [2]: [tip_amount#12526, month#14764]
# Arguments: [month#14764], [partial_percentile_approx(tip_amount#12526, 0.99, 10000, 0, 0) AS buf#16785], [buf#16784], [month#14764, buf#16785], false
#
# (6) PhotonShuffleExchangeSink
# Input [2]: [month#14764, buf#16785]
# Arguments: hashpartitioning(month#14764, 1024)
#
# (7) PhotonShuffleMapStage
# Input [2]: [month#14764, buf#16785]
# Arguments: ENSURE_REQUIREMENTS, [id=#17833]
#
# (8) PhotonShuffleExchangeSource
# Input [2]: [month#14764, buf#16785]
#
# (9) PhotonGroupingAgg
# Input [2]: [month#14764, buf#16785]
# Arguments: [month#14764], [finalmerge_percentile_approx(merge buf#16785) AS percentile_approx(tip_amount, 0.99, 10000)#16783], [percentile_approx(tip_amount, 0.99, 10000)#16783], [month#14764, percentile_approx(tip_amount, 0.99, 10000)#16783 AS 99_tip_amount#16102], true
#
# (10) PhotonShuffleExchangeSink
# Input [2]: [month#14764, 99_tip_amount#16102]
# Arguments: rangepartitioning(month#14764 ASC NULLS FIRST, 1024)
#
# (11) PhotonShuffleMapStage
# Input [2]: [month#14764, 99_tip_amount#16102]
# Arguments: ENSURE_REQUIREMENTS, [id=#17839]
#
# (12) PhotonShuffleExchangeSource
# Input [2]: [month#14764, 99_tip_amount#16102]
#
# (13) PhotonSort
# Input [2]: [month#14764, 99_tip_amount#16102]
# Arguments: [month#14764 ASC NULLS FIRST]
#
# (14) PhotonResultStage
# Input [2]: [month#14764, 99_tip_amount#16102]
#
# (15) ColumnarToRow
# Input [2]: [month#14764, 99_tip_amount#16102]
#
# (16) AdaptiveSparkPlan
# Output [2]: [month#14764, 99_tip_amount#16102]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
sql_avg_trips_by_dow.explain("formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (21)
# +- == Initial Plan ==
#    ColumnarToRow (20)
#    +- PhotonResultStage (19)
#       +- PhotonSort (18)
#          +- PhotonShuffleExchangeSource (17)
#             +- PhotonShuffleMapStage (16)
#                +- PhotonShuffleExchangeSink (15)
#                   +- PhotonGroupingAgg (14)
#                      +- PhotonShuffleExchangeSource (13)
#                         +- PhotonShuffleMapStage (12)
#                            +- PhotonShuffleExchangeSink (11)
#                               +- PhotonGroupingAgg (10)
#                                  +- PhotonGroupingAgg (9)
#                                     +- PhotonShuffleExchangeSource (8)
#                                        +- PhotonShuffleMapStage (7)
#                                           +- PhotonShuffleExchangeSink (6)
#                                              +- PhotonGroupingAgg (5)
#                                                 +- PhotonProject (4)
#                                                    +- PhotonFilter (3)
#                                                       +- PhotonRowToColumnar (2)
#                                                          +- Scan csv  (1)
#
#
# (1) Scan csv
# Output [4]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-01.csv.gz, ... 11 entries]
# PushedFilters: [IsNotNull(trip_distance), IsNotNull(fare_amount), GreaterThan(trip_distance,0.0)]
# ReadSchema: struct<pickup_datetime:timestamp,dropoff_datetime:timestamp,trip_distance:double,fare_amount:string>
#
# (2) PhotonRowToColumnar
# Input [4]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523]
#
# (3) PhotonFilter
# Input [4]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523]
# Arguments: (((((isnotnull(trip_distance#12515) AND isnotnull(fare_amount#12523)) AND (trip_distance#12515 > 0.0)) AND (cast(fare_amount#12523 as int) >= 0)) AND isnotnull(gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false))) AND isnotnull(gettimestamp(dropoff_datetime#12513, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false)))
#
# (4) PhotonProject
# Input [4]: [pickup_datetime#12512, dropoff_datetime#12513, trip_distance#12515, fare_amount#12523]
# Arguments: [gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false) AS pickup_ts#14755, date_format(gettimestamp(pickup_datetime#12512, yyyy-MM-dd HH:mm:ss, TimestampType, try_to_timestamp, Some(Etc/UTC), false), E, Some(Etc/UTC)) AS _groupingexpression#16799]
#
# (5) PhotonGroupingAgg
# Input [2]: [pickup_ts#14755, _groupingexpression#16799]
# Arguments: [_groupingexpression#16799, cast(pickup_ts#14755 as date) AS cast(pickup_ts#14755 as date)#16805], [partial_count(1) AS count#16801L], [count(1)#16801L], [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L], false
#
# (6) PhotonShuffleExchangeSink
# Input [3]: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L]
# Arguments: hashpartitioning(_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, 1024)
#
# (7) PhotonShuffleMapStage
# Input [3]: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L]
# Arguments: ENSURE_REQUIREMENTS, [id=#18037]
#
# (8) PhotonShuffleExchangeSource
# Input [3]: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L]
#
# (9) PhotonGroupingAgg
# Input [3]: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L]
# Arguments: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805], [merge_count(merge count#16801L) AS count#16801L], [count(1)#16801L], [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L], true
#
# (10) PhotonGroupingAgg
# Input [3]: [_groupingexpression#16799, cast(pickup_ts#14755 as date)#16805, count#16801L]
# Arguments: [_groupingexpression#16799], [merge_count(merge count#16801L) AS count#16801L, partial_count(distinct cast(pickup_ts#14755 as date)#16805) AS count#16807L], [count(1)#16801L, count(pickup_ts)#16798L], [_groupingexpression#16799, count#16801L, count#16807L], false
#
# (11) PhotonShuffleExchangeSink
# Input [3]: [_groupingexpression#16799, count#16801L, count#16807L]
# Arguments: hashpartitioning(_groupingexpression#16799, 1024)
#
# (12) PhotonShuffleMapStage
# Input [3]: [_groupingexpression#16799, count#16801L, count#16807L]
# Arguments: ENSURE_REQUIREMENTS, [id=#18045]
#
# (13) PhotonShuffleExchangeSource
# Input [3]: [_groupingexpression#16799, count#16801L, count#16807L]
#
# (14) PhotonGroupingAgg
# Input [3]: [_groupingexpression#16799, count#16801L, count#16807L]
# Arguments: [_groupingexpression#16799], [finalmerge_count(merge count#16801L) AS count(1)#16797L, finalmerge_count(distinct merge count#16807L) AS count(cast(pickup_ts#14755 as date))#16798L], [count(1)#16797L, count(pickup_ts)#16798L], [_groupingexpression#16799 AS dow#16105, (cast(count(1)#16797L as double) / cast(count(pickup_ts)#16798L as double)) AS avg_trips_per_day#16106], true
#
# (15) PhotonShuffleExchangeSink
# Input [2]: [dow#16105, avg_trips_per_day#16106]
# Arguments: rangepartitioning(avg_trips_per_day#16106 DESC NULLS LAST, 1024)
#
# (16) PhotonShuffleMapStage
# Input [2]: [dow#16105, avg_trips_per_day#16106]
# Arguments: ENSURE_REQUIREMENTS, [id=#18051]
#
# (17) PhotonShuffleExchangeSource
# Input [2]: [dow#16105, avg_trips_per_day#16106]
#
# (18) PhotonSort
# Input [2]: [dow#16105, avg_trips_per_day#16106]
# Arguments: [avg_trips_per_day#16106 DESC NULLS LAST]
#
# (19) PhotonResultStage
# Input [2]: [dow#16105, avg_trips_per_day#16106]
#
# (20) ColumnarToRow
# Input [2]: [dow#16105, avg_trips_per_day#16106]
#
# (21) AdaptiveSparkPlan
# Output [2]: [dow#16105, avg_trips_per_day#16106]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.
